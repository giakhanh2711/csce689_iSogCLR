# %%
import visualize

# %%
"""
val result file roughly formatted in this way:

{"val_txt_r1": 11.7, "val_txt_r5": 30.84, "val_txt_r10": 42.34, "val_txt_r_mean": 28.293333333333333, "val_img_r1": 9.148706465672358, "val_img_r5": 24.66711983685873, "val_img_r10": 34.983405973849415, "val_img_r_mean": 22.93307742546017, "val_r_mean": 25.613205379396753, "epoch": 0, "data": "coco"}
epoch: checkpoint_16 {"val_txt_r1": 12.54, "val_txt_r5": 31.1, "val_txt_r10": 42.56, "val_txt_r_mean": 28.733333333333334, "val_img_r1": 9.95241712983326, "val_img_r5": 25.826702387140628, "val_img_r10": 36.22295973449558, "val_img_r_mean": 24.000693083823155, "val_r_mean": 26.367013208578243, "epoch": 0, "data": "coco"}
...
epoch: checkpoint_26 

"""

# %%
visualize.reformat_val_file("val_coco_log_sogclr_adamw.txt")
visualize.plot_mean_recall_val("val_coco_log_sogclr_adamw.txt")
